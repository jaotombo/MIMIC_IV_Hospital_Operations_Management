# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Setup

# %%
# Import useful libraries
import numpy as np
import pandas as pd
from scipy import stats
import os
import re
import pickle
import sys
import time
import psycopg2

# %%
# # Setup Repository
# with open("repo_info.txt", "r") as repo_info:
#     path_to_repo = repo_info.readline()

# path_to_data = f"{path_to_repo}data/"
# path_to_raw = f"{path_to_data}raw/"
# path_to_processed = f"{path_to_data}processed/"

# %% [markdown]
# ## Import Data

# %%
path_to_raw="raw_data"
df_raw = pd.read_csv(f'{path_to_raw}/all_data_raw.csv.gzip', compression = 'gzip')
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625220 entries, 0 to 625219
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   hadm_id                     625220 non-null  int64
#  1   subject_id                  625220 non-null  int64
#  2   admittime                   625220 non-null  object
#  3   dischtime                   625220 non-null  object
#  4   deathtime                   141883 non-null  object
#  5   race                        625220 non-null  object
#  6   admission_type              625220 non-null  object
#  7   admission_location          625220 non-null  object
#  8   insurance                   625220 non-null  object
#  9   language                    625220 non-null  object
#  10  marital_status              578293 non-null  object
#  11  discharge_location          624494 non-null  object
#  12  first_careunit              625220 non-null  object
#  13  last_careunit               625220 non-null  object
#  14  icu_los                     625220 non-null  float64
#  15  prev_service                223412 non-null  object
#  16  curr_service                625220 non-null  object
#  17  gender                      625220 non-null  object
#  18  age                         625220 non-null  int64
#  19  urea_n_min                  624893 non-null  float64
#  20  urea_n_max                  624893 non-null  float64
#  21  urea_n_mean                 624893 non-null  float64
#  22  platelets_min               624845 non-null  float64
#  23  platelets_max               624845 non-null  float64
#  24  platelets_mean              624845 non-null  float64
#  25  magnesium_max               624630 non-null  float64
#  26  albumin_min                 511332 non-null  float64
#  27  calcium_min                 621093 non-null  float64
#  28  resprate_min                625172 non-null  float64
#  29  resprate_max                625172 non-null  float64
#  30  resprate_mean               625172 non-null  float64
#  31  glucose_min                 624504 non-null  float64
#  32  glucose_max                 624504 non-null  float64
#  33  glucose_mean                624504 non-null  float64
#  34  hr_min                      625219 non-null  float64
#  35  hr_max                      625219 non-null  float64
#  36  hr_mean                     625219 non-null  float64
#  37  sysbp_min                   625066 non-null  float64
#  38  sysbp_max                   625066 non-null  float64
#  39  sysbp_mean                  625066 non-null  float64
#  40  diasbp_min                  625066 non-null  float64
#  41  diasbp_max                  625066 non-null  float64
#  42  diasbp_mean                 625066 non-null  float64
#  43  temp_min                    624086 non-null  float64
#  44  temp_max                    624086 non-null  float64
#  45  temp_mean                   624086 non-null  float64
#  46  sapsii                      625220 non-null  int64
#  47  sofa_24hours                625220 non-null  int64
#  48  urine_min                   625220 non-null  float64
#  49  urine_mean                  625220 non-null  float64
#  50  urine_max                   625220 non-null  float64
#  51  charlson_comorbidity_index  625220 non-null  int64
#  52  patientweight               625126 non-null  float64
#  53  icd_code                    625220 non-null  object
#  54  proc_icd                    625220 non-null  object
#  55  diag_icd                    625220 non-null  object
#  56  age_cat                     625220 non-null  int64
#  57  type_stay                   625215 non-null  object
#  58  prev_adm                    625220 non-null  object
#  59  dest_discharge              625220 non-null  object
#  60  emergency_dpt               625220 non-null  object
#  61  icd_chapter                 625220 non-null  int64
#  62  origin_patient              625220 non-null  object
# dtypes: float64(32), int64(8), object(23)
# memory usage: 300.5+ MB

# %%
#Then we drop any duplicates
# df = df_raw.drop_duplicates(subset=['hadm_id']).reset_index()
# df = df_raw.drop_duplicates()

# %%
#Because there are some subtle differences between the records belonging to the same hadm id, we can do some process
#For float column difference, we extract the average value
#For others, we keep the mode value
def aggregate_mode(x):
    modes = stats.mode(x)[0]
    return modes[0] if len(modes) else np.nan

def custom_agg(series):
    if series.dtype == float:
        return series.mean()
    else:
        return aggregate_mode(series)

diff_cols_per_group = df_raw.groupby('hadm_id').agg(lambda x: x.nunique(dropna=False) > 1)
cols_to_aggregate = diff_cols_per_group.any()
df = df_raw.groupby('hadm_id').agg({col: custom_agg for col in df_raw.columns if col in cols_to_aggregate and col != 'hadm_id'})

df.head()
# Out:
# C:\Users\14297\AppData\Local\Temp\ipykernel_21296\3656087538.py:5: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   modes = stats.mode(x)[0]
# C:\Users\14297\AppData\Local\Temp\ipykernel_21296\3656087538.py:5: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   modes = stats.mode(x)[0]
#           subject_id            admittime            dischtime  \
# hadm_id
# 20000094    14046553  2150-03-02 00:00:00  2150-03-03 09:21:00
# 20000147    14990224  2121-08-30 16:33:00  2121-09-03 15:45:00
# 20000808    16788749  2180-01-12 20:59:00  2180-01-25 12:10:00
# 20001305    16003661  2178-03-25 02:58:00  2178-03-27 19:23:00
# 20001361    14577567  2143-05-04 14:55:00  2143-05-18 16:58:00
#
#                     deathtime                    race     admission_type  \
# hadm_id
# 20000094  2150-03-03 09:21:00                   WHITE             URGENT
# 20000147                  NaN  WHITE - OTHER EUROPEAN             URGENT
# 20000808                  NaN                   WHITE           EW EMER.
# 20001305  2178-03-27 19:23:00                   WHITE  OBSERVATION ADMIT
# 20001361                  NaN                   WHITE           EW EMER.
#
#               admission_location insurance language marital_status  ...  \
# hadm_id                                                             ...
# 20000094  TRANSFER FROM HOSPITAL     Other  ENGLISH        WIDOWED  ...
# 20000147  TRANSFER FROM HOSPITAL  Medicare  ENGLISH        MARRIED  ...
# 20000808          EMERGENCY ROOM     Other  ENGLISH         SINGLE  ...
# 20001305          EMERGENCY ROOM  Medicare  ENGLISH         SINGLE  ...
# 20001361          EMERGENCY ROOM  Medicaid  ENGLISH         SINGLE  ...
#
#          icd_code                                 proc_icd  \
# hadm_id
# 20000094  I509                                           0
# 20000147  I213     02100Z9,B211YZZ,021209W,06BQ4ZZ,5A1221Z
# 20000808  2252                         0151,0239,0239,0212
# 20001305  J9601                    5A1945Z,0BH17EZ,02HV33Z
# 20001361  3481                9604,9671,3893,3891,0331,966
#
#                                                    diag_icd  age_cat  \
# hadm_id
# 20000094  I509   ,K7200  ,R570   ,N179   ,I2510  ,Z9861 ...        4
# 20000147  I213   ,I5021  ,E1121  ,E1165  ,I25119 ,I110  ...        4
# 20000808  2252   ,3485   ,3313   ,311    ,53081  ,4019  ...        3
# 20001305  J9601  ,I214   ,R578   ,N170   ,R64    ,D684  ...        4
# 20001361  3481   ,5845   ,51881  ,72888  ,34839  ,30401 ...        2
#
#            type_stay              prev_adm dest_discharge  emergency_dpt  \
# hadm_id
# 20000094   1-Medical  1-No hospitalization        2-Other            Yes
# 20000147  3-Surgical  1-No hospitalization        2-Other            Yes
# 20000808  3-Surgical  1-No hospitalization         1-Home             No
# 20001305   1-Medical  1-No hospitalization        2-Other             No
# 20001361   1-Medical  1-No hospitalization        2-Other             No
#
#           icd_chapter  origin_patient
# hadm_id
# 20000094           29         2-Other
# 20000147           29         2-Other
# 20000808            2         2-Other
# 20001305           30         2-Other
# 20001361            6         2-Other
#
# [5 rows x 62 columns]

# %%
# And print info our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48924 entries, 20000094 to 29999828
# Data columns (total 62 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   subject_id                  48924 non-null  int64
#  1   admittime                   48924 non-null  object
#  2   dischtime                   48924 non-null  object
#  3   deathtime                   5885 non-null   object
#  4   race                        48924 non-null  object
#  5   admission_type              48924 non-null  object
#  6   admission_location          48924 non-null  object
#  7   insurance                   48924 non-null  object
#  8   language                    48924 non-null  object
#  9   marital_status              45077 non-null  object
#  10  discharge_location          48732 non-null  object
#  11  first_careunit              48924 non-null  object
#  12  last_careunit               48924 non-null  object
#  13  icu_los                     48924 non-null  float64
#  14  prev_service                10743 non-null  object
#  15  curr_service                48924 non-null  object
#  16  gender                      48924 non-null  object
#  17  age                         48924 non-null  int64
#  18  urea_n_min                  48782 non-null  float64
#  19  urea_n_max                  48782 non-null  float64
#  20  urea_n_mean                 48782 non-null  float64
#  21  platelets_min               48764 non-null  float64
#  22  platelets_max               48764 non-null  float64
#  23  platelets_mean              48764 non-null  float64
#  24  magnesium_max               48663 non-null  float64
#  25  albumin_min                 27587 non-null  float64
#  26  calcium_min                 47677 non-null  float64
#  27  resprate_min                48907 non-null  float64
#  28  resprate_max                48907 non-null  float64
#  29  resprate_mean               48907 non-null  float64
#  30  glucose_min                 48602 non-null  float64
#  31  glucose_max                 48602 non-null  float64
#  32  glucose_mean                48602 non-null  float64
#  33  hr_min                      48923 non-null  float64
#  34  hr_max                      48923 non-null  float64
#  35  hr_mean                     48923 non-null  float64
#  36  sysbp_min                   48892 non-null  float64
#  37  sysbp_max                   48892 non-null  float64
#  38  sysbp_mean                  48892 non-null  float64
#  39  diasbp_min                  48892 non-null  float64
#  40  diasbp_max                  48892 non-null  float64
#  41  diasbp_mean                 48892 non-null  float64
#  42  temp_min                    48689 non-null  float64
#  43  temp_max                    48689 non-null  float64
#  44  temp_mean                   48689 non-null  float64
#  45  sapsii                      48924 non-null  int64
#  46  sofa_24hours                48924 non-null  int64
#  47  urine_min                   48924 non-null  float64
#  48  urine_mean                  48924 non-null  float64
#  49  urine_max                   48924 non-null  float64
#  50  charlson_comorbidity_index  48924 non-null  int64
#  51  patientweight               48887 non-null  float64
#  52  icd_code                    48924 non-null  object
#  53  proc_icd                    48924 non-null  object
#  54  diag_icd                    48924 non-null  object
#  55  age_cat                     48924 non-null  int64
#  56  type_stay                   48924 non-null  object
#  57  prev_adm                    48924 non-null  object
#  58  dest_discharge              48924 non-null  object
#  59  emergency_dpt               48924 non-null  object
#  60  icd_chapter                 48924 non-null  int64
#  61  origin_patient              48924 non-null  object
# dtypes: float64(32), int64(7), object(23)
# memory usage: 23.5+ MB

# %%
# Convert the deathtime column to a datetime-column
df['deathtime'] = pd.to_datetime(df.deathtime, errors = 'coerce')
# Remove any observation with a recorded death case
df_clean = df[np.isnat(df['deathtime'])].copy()
print(f"Number of observations with a deathtime: {df.shape[0] - df_clean.shape[0]}")
# Out:
# Number of observations with a deathtime: 5885

# %%
# We then remove all patients below 18 years old
df_clean = df_clean.loc[df_clean.age >= 18]
print(f"N. of observations: {df_clean.shape[0]}")
# Out:
# N. of observations: 43039

# %%
df_clean.to_csv("df_clean.csv")

# %% [markdown]
# # Merge notes data into the dataset

# %% [markdown]
# ## Process notes to get discharge notes

# %%
# #The following is based on personal psql setting
# host = 'localhost'  
# port = '5432'  
# sqluser = 'postgres'  
# password = 'mydb'  
# dbname = 'mimiciv' 
# schema_name1 = 'mimiciv_hosp' 
# schema_name2 = 'mimiciv_icu'
# schema_name3 = 'mimiciv_derived' 
# schema_name4 = 'mimiciv_note'
# schema_search_path = f"{schema_name1}, {schema_name2}, {schema_name3}, {schema_name4}"


# try:
#     con = psycopg2.connect(
#         host=host,
#         port=port,
#         database=dbname,
#         user=sqluser,
#         password=password
#     )

#     # due to the difference in data structure, notes in mimiciv is a table that we create(materialized view)

#     query = \
#     """
#     select * from note_filter
#     """
#     # Connect to local postgres version of mimic
#     con = psycopg2.connect(host='localhost', database=dbname, user=sqluser, password=password)
#     cur = con.cursor()

#     # Perform SQL query
#     cur.execute('SET search_path to ' + schema_search_path)
#     text = pd.read_sql_query(query,con)

# finally:
#     if con is not None:
#         con.close()
# Out:
# C:\Users\14297\AppData\Local\Temp\ipykernel_8064\2552751421.py:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   text = pd.read_sql_query(query,con)

# %%
text_d=pd.read_csv("../datasets/discharge_note.csv")
text_r=pd.read_csv("../datasets/radiology_note.csv")

# %%
text_d.head()
# Out:
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    10004749  28691602  2127-04-04 20:01:00  2127-04-07 17:56:00       NaN
# 1    10005001  25115899  2164-10-12 00:00:00  2164-10-14 17:24:00       NaN
# 2    10005123  20470681  2129-08-17 17:45:00  2129-08-19 16:04:00       NaN
# 3    10005565  29140012  2180-08-21 23:01:00  2180-08-22 18:50:00       NaN
# 4    10005605  24283979  2120-05-20 23:48:00  2120-05-23 14:30:00       NaN
#
#                        first_careunit                       last_careunit  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2  Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    age gender marital_status insurance  \
# 0   32      F         SINGLE     Other
# 1   40      F         SINGLE     Other
# 2   54      M        MARRIED     Other
# 3   61      F        MARRIED     Other
# 4   62      F         SINGLE     Other
#
#                                       discharge_text
# 0   \nName:  ___                Unit No:   ___\n ...
# 1   \nName:  ___               Unit No:   ___\n \...
# 2   \nName:  ___                  Unit No:   ___\...
# 3   \nName:  ___                        Unit No: ...
# 4   \nName:  ___                    Unit No:   __...

# %%
# text=pd.read_csv("../dataset/note_filter.csv", index=False)
text = pd.merge(text_d, text_r, 
                       on="hadm_id", 
                       how="outer", 
                       suffixes=('_dn', '_rn'))

# %%
#Fillna in discharge with radiology records
for column in text.columns:
    if column not in ['discharge_text', 'radiology_text', 'hadm_id']:
        if '_dn' in column:
            corresponding_radiology_column = column.replace('_dn', '_rn')
            text[column] = text[column].fillna(text[corresponding_radiology_column])
columns_to_drop = [column for column in text.columns if '_rn' in column]
text.drop(columns=columns_to_drop, inplace=True)

text.columns = [column.replace('_dn', '') for column in text.columns]

# %%
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1736566 entries, 0 to 1736565
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   subject_id      float64
#  1   hadm_id         int64
#  2   admittime       object
#  3   dischtime       object
#  4   deathtime       object
#  5   first_careunit  object
#  6   last_careunit   object
#  7   age             float64
#  8   gender          object
#  9   marital_status  object
#  10  insurance       object
#  11  discharge_text  object
#  12  radiology_text  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 185.5+ MB

# %%
text['subject_id'] = text['subject_id'].astype('Int64')
text['age'] = text['age'].astype('Int64')
text['admittime'] = pd.to_datetime(text['admittime'])
text['dischtime'] = pd.to_datetime(text['dischtime'])
text['deathtime'] = pd.to_datetime(text['deathtime'])

# %%
text.head()
# Out:
#    subject_id   hadm_id           admittime           dischtime deathtime  \
# 0    10004749  28691602 2127-04-04 20:01:00 2127-04-07 17:56:00       NaT
# 1    10004749  28691602 2127-04-04 20:01:00 2127-04-07 17:56:00       NaT
# 2    10005001  25115899 2164-10-12 00:00:00 2164-10-14 17:24:00       NaT
# 3    10005123  20470681 2129-08-17 17:45:00 2129-08-19 16:04:00       NaT
# 4    10005123  20470681 2129-08-17 17:45:00 2129-08-19 16:04:00       NaT
#
#                        first_careunit                       last_careunit  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3  Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
# 4  Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
#
#    age gender marital_status insurance  \
# 0   32      F         SINGLE     Other
# 1   32      F         SINGLE     Other
# 2   40      F         SINGLE     Other
# 3   54      M        MARRIED     Other
# 4   54      M        MARRIED     Other
#
#                                       discharge_text  \
# 0   \nName:  ___                Unit No:   ___\n ...
# 1   \nName:  ___                Unit No:   ___\n ...
# 2   \nName:  ___               Unit No:   ___\n \...
# 3   \nName:  ___                  Unit No:   ___\...
# 4   \nName:  ___                  Unit No:   ___\...
#
#                                       radiology_text
# 0  INDICATION:  Severe abdominal and pelvic pain....
# 1  INDICATION:  Pelvic pain.\n\nCOMPARISONS:  CT ...
# 2                                                NaN
# 3  INDICATION:  ___ year old man with congenital ...
# 4  EXAMINATION:  CHEST (PORTABLE AP)\n\nINDICATIO...

# %%
# Remove any duplicates
text.drop_duplicates(inplace = True)

# %%
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1263674 entries, 0 to 1736565
# Data columns (total 13 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   subject_id      1263674 non-null  Int64
#  1   hadm_id         1263674 non-null  int64
#  2   admittime       1263674 non-null  datetime64[ns]
#  3   dischtime       1263674 non-null  datetime64[ns]
#  4   deathtime       104684 non-null   datetime64[ns]
#  5   first_careunit  568516 non-null   object
#  6   last_careunit   568516 non-null   object
#  7   age             1263674 non-null  Int64
#  8   gender          1263674 non-null  object
#  9   marital_status  1204778 non-null  object
#  10  insurance       1263674 non-null  object
#  11  discharge_text  1187654 non-null  object
#  12  radiology_text  1199050 non-null  object
# dtypes: Int64(2), datetime64[ns](3), int64(1), object(7)
# memory usage: 137.4+ MB

# %%
text.head()
# Out:
#    subject_id   hadm_id           admittime           dischtime deathtime  \
# 0    10004749  28691602 2127-04-04 20:01:00 2127-04-07 17:56:00       NaT
# 1    10004749  28691602 2127-04-04 20:01:00 2127-04-07 17:56:00       NaT
# 2    10005001  25115899 2164-10-12 00:00:00 2164-10-14 17:24:00       NaT
# 3    10005123  20470681 2129-08-17 17:45:00 2129-08-19 16:04:00       NaT
# 4    10005123  20470681 2129-08-17 17:45:00 2129-08-19 16:04:00       NaT
#
#                        first_careunit                       last_careunit  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3  Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
# 4  Medical Intensive Care Unit (MICU)  Medical Intensive Care Unit (MICU)
#
#    age gender marital_status insurance  \
# 0   32      F         SINGLE     Other
# 1   32      F         SINGLE     Other
# 2   40      F         SINGLE     Other
# 3   54      M        MARRIED     Other
# 4   54      M        MARRIED     Other
#
#                                       discharge_text  \
# 0   \nName:  ___                Unit No:   ___\n ...
# 1   \nName:  ___                Unit No:   ___\n ...
# 2   \nName:  ___               Unit No:   ___\n \...
# 3   \nName:  ___                  Unit No:   ___\...
# 4   \nName:  ___                  Unit No:   ___\...
#
#                                       radiology_text
# 0  INDICATION:  Severe abdominal and pelvic pain....
# 1  INDICATION:  Pelvic pain.\n\nCOMPARISONS:  CT ...
# 2                                                NaN
# 3  INDICATION:  ___ year old man with congenital ...
# 4  EXAMINATION:  CHEST (PORTABLE AP)\n\nINDICATIO...

# %% [markdown]
# Our discharge notes are not unique for the combination subject_id and hadm_id. We will merge all the notes.

# %%
print(f"Number of duplicate text: {round(text.duplicated(subset = ['subject_id', 'hadm_id']).sum()/text.shape[0]*100, 2)}%")
# Out:
# Number of duplicate text: 70.38%

# %%
text['discharge_text'] = text.groupby(['subject_id', 'hadm_id', 'admittime']).discharge_text.transform(lambda x: '\n'.join(x.astype(str)))
text['radiology_text'] = text.groupby(['subject_id', 'hadm_id', 'admittime']).radiology_text.transform(lambda x: '\n'.join(x.astype(str)))

# %%
text_clean = text[['hadm_id', 'subject_id', 'discharge_text','radiology_text']].drop_duplicates()
print(f"Duplicates removed: {text.shape[0] - text_clean.shape[0]}")

# %% [markdown]
# ## Merge together

# %%
df_full = pd.merge(df_clean, text_clean, on = ['hadm_id', 'subject_id'], indicator = True, how = 'left', validate = '1:1')
print(f"Check merges:\n{df_full._merge.value_counts()}")

# %%
# Now remove the failed merges
df_full = df_full.loc[df_full._merge == 'both']
df_full.drop(columns = ['_merge'], inplace = True)

# %%
# Finally save the file to a CSV
path_to_processed = "processed_data"
df_full.to_csv(f'{path_to_processed}/df_mixed.csv.gzip', compression = 'gzip', index = False)
